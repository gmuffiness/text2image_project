# %% [markdown]
# 1. Prepare Dataset

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
# %cd /content/gdrive/My Drive/dl_teamproject_folder
# Out:
# /content/gdrive/My Drive/dl_teamproject_folder

# %%
ls
# Out:
#  birds/
#  CUB_200_2011/
# 'dataset stage1_generator_discriminator'
#  dataset_stage1_generator_discriminator_stage2_generator.ipynb
# 'dataset stage1_generator.ipynb의 사본'
#  inception_finetuned_models/
#  logs/
#  results_BN_Adam/
# 'results_BN_Adam_lr x 10'/
#  results_BN_Adam_WL_Dropout/
#  results_NBN_RMSprop/
#  results_wgan_rmsprop/
#  StackGAN-inception-model-master/
#  StackGAN_PT_material.ipynb
# 'stage12-gan.ipynb의 사본'
#  Stage1_discriminator.ipynb
#  stage1_gen2.h5
#  stage1_results/
#  stage2-gan.ipynb
# '이재철 stage 2.ipynb'
#  test2.ipynb
#  test.ipynb

# %%
ls
# Out:
#  birds/
#  CUB_200_2011/
# 'dataset stage1_generator_discriminator'
#  dataset_stage1_generator_discriminator_stage2_generator.ipynb
# 'dataset stage1_generator.ipynb의 사본'
#  inception_finetuned_models/
#  logs/
#  results_BN_Adam/
# 'results_BN_Adam_lr x 10'/
#  results_BN_Adam_WL_Dropout/
#  results_NBN_RMSprop/
#  results_wgan_rmsprop/
#  StackGAN-inception-model-master/
#  StackGAN_PT_material.ipynb
# 'stage12-gan.ipynb의 사본'
#  Stage1_discriminator.ipynb
#  stage1_gen2.h5
#  stage1_results/
#  stage2-gan.ipynb
# '이재철 stage 2.ipynb'
#  test2.ipynb
#  test.ipynb

# %%
# %cd StackGAN-inception-model-master/
# Out:
# /content/gdrive/My Drive/dl_teamproject_folder/StackGAN-inception-model-master

# %%
ls
# Out:
# inception/  inception_score.py  README.md

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# %%
tf.__version__
# Out:
# '2.2.0'

# %%
# !python inception_score.py --image_folder stage1_results
# Out:
# 2020-06-21 10:49:26.947862: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# stage1_results
# 2020-06-21 10:49:28.863912: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2200000000 Hz
# 2020-06-21 10:49:28.864168: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2c74bc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-06-21 10:49:28.864208: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-06-21 10:49:28.866252: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-06-21 10:49:28.869264: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-06-21 10:49:28.869306: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (9da7823fac76): /proc/driver/nvidia/version does not exist
# Traceback (most recent call last):
#   File "inception_score.py", line 233, in <module>
#     tf.app.run()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/platform/app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/usr/local/lib/python3.6/dist-packages/absl/app.py", line 299, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.6/dist-packages/absl/app.py", line 250, in _run_main
#     sys.exit(main(argv))
#   File "inception_score.py", line 211, in main
#     logits, _ = inference(inputs, num_classes)
#   File "inception_score.py", line 185, in inference
#     scope=scope)
#   File "/content/gdrive/My Drive/dl_teamproject_folder/StackGAN-inception-model-master/inception/slim/inception_model.py", line 80, in inception_v3
#     with tf.name_scope(scope, 'inception_v3', [inputs]):
# TypeError: __init__() takes 2 positional arguments but 4 were given

# %%
from math import floor
from numpy import ones
from numpy import expand_dims
from numpy import log
from numpy import mean
from numpy import std
from numpy import exp
from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input
# Out:
# Using TensorFlow backend.

# %%
ls
# Out:
#  birds/
#  CUB_200_2011/
# 'dataset stage1_generator_discriminator'
#  dataset_stage1_generator_discriminator_stage2_generator.ipynb
# 'dataset stage1_generator.ipynb의 사본'
#  inception_finetuned_models/
#  inception_score.py
#  inception_score_test.ipynb
#  logs/
#  results_BN_Adam/
# 'results_BN_Adam_lr x 10'/
#  results_BN_Adam_WL_Dropout/
#  results_NBN_RMSprop/
#  results_wgan_rmsprop/
#  StackGAN-inception-model-master/
#  StackGAN_PT_material.ipynb
# 'stage12-gan.ipynb의 사본'
#  Stage1_discriminator.ipynb
#  stage1_gen2.h5
#  stage1_results/
#  stage2-gan.ipynb
# '이재철 stage 2.ipynb'
#  test2.ipynb

# %%
from IPython.display import Image, display

display(Image('results_wgan_rmsprop/gen_180_9.png'))

# %%
import PIL
import numpy as np
from PIL import Image

# %%
test_image = Image.open('stage1_results/gen_592_2.png')
# image2 = Image.open('results_wgan_rmsprop/gen_0_9.png')
# image3 = Image.open('results_wgan_rmsprop/gen_72_9.png')


test_data = np.asarray(test_image)
# data2 = np.asarray(image2)
# data3 = np.asarray(image3)
print(test_data.shape)
# print(data1[:,:,0])

# data = [data1,data2,data3]
# data = np.asarray(data)

# test = [1,data1]
# test2 = np.asarray(test)
# test2.shape

data = np.reshape(data1,((1,)+test_data.shape))
print(data.shape)
# Out:
# (288, 432, 4)
# (1, 288, 432, 4)

# %%
image1 = Image.open('stage1_results/gen_592_2.png')
image2 = Image.open('stage1_results/gen_592_3.png')
image3 = Image.open('stage1_results/gen_592_4.png')


data1 = np.asarray(test_image)
data2 = np.asarray(image2)
data3 = np.asarray(image3)
print(test_data.shape)
# print(data1[:,:,0])

data = [data1,data2,data3]
data = np.asarray(data)

# test = [1,data1]
# test2 = np.asarray(test)
# test2.shape

# data = np.reshape(data,((1,)+test_data.shape))
print(data.shape)
# Out:
# (288, 432, 4)
# (3, 288, 432, 4)

# %%
subset = scale_images(data, (299,299,3))

# %%
subset = preprocess_input(subset)

# %%
model = InceptionV3()

# %%
p_yx = model.predict(subset)

# %%
p_y = expand_dims(p_yx.mean(axis=0), 0)

# %%
kl_d = p_yx * (log(p_yx) - log(p_y))

# %%
sum_kl_d = kl_d.sum(axis=1)

# %%
avg_kl_d = mean(sum_kl_d)

# %%
is_score = exp(avg_kl_d)

# %%
scores = []
scores.append(is_score)

# %%
is_avg, is_std = mean(scores), std(scores)

# %%
print(is_avg,is_std)
# Out:
# 1.0107127 0.0

# %%
import PIL
import numpy as np
from PIL import Image
image = Image.open('results_wgan_rmsprop/gen_180_9.png')
image2 = Image.open('stage1_results/gen_194_9.png')
image3 = Image.open('stage1_results/gen_192_9.png')
# print(image.format)
# print(image.size)
# print(image.mode)
data1 = np.asarray(image)
data2 = np.asarray(image2)
data3 = np.asarray(image3)
data = [data1,data2,data3]
data = np.asarray(data)
print(data.shape)
print(data[:,:,100:-100,0])
# load_image.show()
# print('loaded', images.shape)
# calculate inception score
# is_avg, is_std = calculate_inception_score(images)
# print('score', is_avg, is_std)
# Out:
# (3, 288, 432, 4)
# [[[255 255 255 ... 255 255 255]
#   [255 255 255 ... 255 255 255]
#   [255 255 255 ... 255 255 255]
#   ...
#   [255 255 255 ... 255 255 255]
#   [255 255 255 ... 255 255 255]
#   [255 255 255 ... 255 255 255]]
#
#  [[255 255 255 ... 255 255 255]
#   [255 255 255 ... 255 255 255]
#   [255 255 255 ... 255 255 255]
#   ...
#   [255 255 255 ... 255 255 255]
#   [255 255 255 ... 255 255 255]
#   [255 255 255 ... 255 255 255]]
#
#  [[255 255 255 ... 255 255 255]
#   [255 255 255 ... 255 255 255]
#   [255 255 255 ... 255 255 255]
#   ...
#   [255 255 255 ... 255 255 255]
#   [255 255 255 ... 255 255 255]
#   [255 255 255 ... 255 255 255]]]

# %%
from math import floor
from numpy import ones
from numpy import expand_dims
from numpy import log
from numpy import mean
from numpy import std
from numpy import exp
from numpy.random import shuffle
from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input
from keras.datasets import cifar10
from skimage.transform import resize
from numpy import asarray
 
# scale an array of images to a new size
def scale_images(images, new_shape):
	images_list = list()
	for image in images:
		# resize with nearest neighbor interpolation
		new_image = resize(image, new_shape, 0)
		# store
		images_list.append(new_image)
	return asarray(images_list)
 
# assumes images have any shape and pixels in [0,255]
def calculate_inception_score(images, n_split=10, eps=1E-16):
	# load inception v3 model
	model = InceptionV3()
	# enumerate splits of images/predictions
	scores = list()
	n_part = floor(images.shape[0] / n_split)
	for i in range(n_split):
		# retrieve images
		ix_start, ix_end = i * n_part, (i+1) * n_part
		subset = images[ix_start:ix_end]
		# convert from uint8 to float32
		subset = subset.astype('float32')
		# scale images to the required size
		subset = scale_images(subset, (299,299,3))
		# pre-process images, scale to [-1,1]
		subset = preprocess_input(subset)
		# predict p(y|x)
		p_yx = model.predict(subset)
		# calculate p(y)
		p_y = expand_dims(p_yx.mean(axis=0), 0)
		# calculate KL divergence using log probabilities
		kl_d = p_yx * (log(p_yx + eps) - log(p_y + eps))
		# sum over classes
		sum_kl_d = kl_d.sum(axis=1)
		# average over images
		avg_kl_d = mean(sum_kl_d)
		# undo the log
		is_score = exp(avg_kl_d)
		# store
		scores.append(is_score)
	# average across images
	is_avg, is_std = mean(scores), std(scores)
	return is_avg, is_std
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2812     try:
# -> 2813         fp.seek(0)
#    2814     except (AttributeError, io.UnsupportedOperation):
#
# AttributeError: 'str' object has no attribute 'seek'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-ecfa9f719c24> in <module>()
#      63 from PIL import Image
#      64 # Open the image form working directory
# ---> 65 image = Image.open('')
#      66
#      67
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2813         fp.seek(0)
#    2814     except (AttributeError, io.UnsupportedOperation):
# -> 2815         fp = io.BytesIO(fp.read())
#    2816         exclusive_fp = True
#    2817
#
# AttributeError: 'str' object has no attribute 'read'

# %%
image1 = Image.open('image/gen_592_9.png')
image2 = Image.open('image/gen_590_2.png')
image3 = Image.open('image/gen_458_8.png')

data1 = np.asarray(image1)
data2 = np.asarray(image2)
data3 = np.asarray(image3)

data = [data1,data2,data3]
data = np.asarray(data)
print(data1.shape)
# test = [1,data1]
# test2 = np.asarray(test)
# test2.shape

# data = np.reshape(data,((1,)+test_data.shape))
print(data.shape)
# Out:
# (213, 216, 4)
# (3,)

# %%
image1 = Image.open('stage1_results/gen_590_0.png')
image2 = Image.open('stage1_results/gen_590_3.png')
image3 = Image.open('stage1_results/gen_590_5.png')
image4 = Image.open('stage1_results/gen_590_6.png')
image5 = Image.open('stage1_results/gen_590_8.png')
image6 = Image.open('stage1_results/gen_590_9.png')
image7 = Image.open('stage1_results/gen_592_1.png')
image8 = Image.open('stage1_results/gen_592_7.png')
image9 = Image.open('stage1_results/gen_556_6.png')
image10 = Image.open('stage1_results/gen_556_9.png')

data1 = np.asarray(image1)
data2 = np.asarray(image2)
data3 = np.asarray(image3)
data4 = np.asarray(image4)
data5 = np.asarray(image5)
data6 = np.asarray(image6)
data7 = np.asarray(image7)
data8 = np.asarray(image8)
data9 = np.asarray(image9)
data10 = np.asarray(image10)
print(test_data.shape)

dataset1 = [data1,data2,data3,data4,data5,data6,data7,data8,data9,data10]
dataset1 = np.asarray(dataset1)
print(dataset1.shape)
# Out:
# (288, 432, 4)
# (10, 288, 432, 4)

# %%
subset1 = scale_images(data1, (299,299,3))
subset2 = scale_images(data2, (299,299,3))
subset3 = scale_images(data3, (299,299,3))

subset1.shape
# Out:
# (213, 299, 299, 3)

# %%
calculate_inception_score(data1, n_split=1, eps=1E-16)
# Out:
# (1.6247207, 0.0)

# %%
calculate_inception_score(data2, n_split=1, eps=1E-16)
# Out:
# (1.3607476, 0.0)

# %%
calculate_inception_score(data3, n_split=1, eps=1E-16)
# Out:
# (1.9566283, 0.0)

# %%
calculate_inception_score(dataset1, n_split=1, eps=1E-16)
# Out:
# (1.439115, 0.0)

# %%
data1.shape
# Out:
# (288, 432, 4)

# %%
data1[100:-100,100:-100,0]
# Out:
# array([[255, 255, 255, ..., 108, 108, 255],
#        [255, 255, 255, ..., 108, 108, 255],
#        [255, 255, 255, ..., 110, 110, 255],
#        ...,
#        [255, 255, 255, ..., 121, 121, 255],
#        [255, 255, 255, ..., 121, 121, 255],
#        [255, 255, 255, ..., 131, 131, 255]], dtype=uint8)
