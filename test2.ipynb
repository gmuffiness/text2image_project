# %%
# !git clone https://github.com/hanzhanggit/StackGAN.git
# Out:
# Cloning into 'StackGAN'...
# remote: Enumerating objects: 103, done.
# remote: Total 103 (delta 0), reused 0 (delta 0), pack-reused 103
# Receiving objects: 100% (103/103), 1.88 MiB | 19.41 MiB/s, done.
# Resolving deltas: 100% (37/37), done.

# %%
# !python --version
# Out:
# Python 3.6.9

# %%
ls
# Out:
# sample_data/  StackGAN/

# %%
# %cd StackGAN
# Out:
# /content/StackGAN

# %%
ls
# Out:
# Data/  demo/  examples/  LICENSE  misc/  models/  README.md*  stageI/  stageII/

# %%
# %cd Data
# Out:
# /content/StackGAN/Data

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-9a8f1dcd-adb4-4a6c-a1a4-9116f2cc0402" name="files[]" multiple disabled />
#      <output id="result-9a8f1dcd-adb4-4a6c-a1a4-9116f2cc0402">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
